# %%
from dataclasses import dataclass
import torch
import torch.nn as nn
from torch.nn import functional as F
import math

# %%
print("PyTorch version:", torch.__version__)
# Out:
# PyTorch version: 2.11.0+xpu

# %%
@dataclass
class GPTConfig:
    vocab_size: int = 50257
    block_size: int = 1024
    n_layer: int = 12
    n_head: int = 12   
    n_embd: int = 768
    # vocab_size: int = 65
    # block_size: int = 256
    # n_layer: int = 6
    # n_head: int = 6
    # n_embd: int = 384
    # dropout: float = 0.1

# %%
class CasualSelfAttention(nn.Module):
    def __init__(self, config: GPTConfig):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd)
        self.c_proj = nn.Linear(config.n_embd, config.n_embd)
        self.c_proj.NANOGPT_SCALE_INIT = 1
        self.n_head = config.n_head
        self.n_embed = config.n_embd
        self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size)).view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size()
        qkv = self.c_attn(x)
        q, k, v = qkv.split(self.n_embed, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:, :, :T, :T] == 0, float("-inf"))
        att = F.softmax(att, dim=-1)
        y = att @ v
        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.c_proj(y)
        return y

# %%
class MLP(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.c_fc = nn.Linear(config.n_embd, 4 * config.n_embd)
        self.gelu = nn.GELU(approximate='tanh')
        self.c_proj = nn.Linear(4 * config.n_embd, config.n_embd)
        #self.dropout = nn.Dropout(config.dropout)

    def forward(self, x):
        x = self.c_fc(x)
        x = self.gelu(x)
        x = self.c_proj(x)
        #x = self.dropout(x)
        return x

# %%
class Block(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.ln1 = nn.LayerNorm(config.n_embd)
        self.ln2 = nn.LayerNorm(config.n_embd)
        self.attn = CasualSelfAttention(config)
        self.mlp = MLP(config)
        #self.attn = nn.MultiheadAttention(config.n_embd, config.n_head, dropout=config.dropout)
        # self.mlp = nn.Sequential(
        #     nn.Linear(config.n_embd, 4 * config.n_embd),
        #     nn.GELU(),
        #     nn.Linear(4 * config.n_embd, config.n_embd),
        #     nn.Dropout(config.dropout),
        # )

    def forward(self, x):
        x = x + self.attn(self.ln1(x))
        x = x + self.mlp(self.ln2(x))
        return x

# %%
class GPT(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size, config.n_embd),
            wpe = nn.Embedding(config.block_size, config.n_embd),
            #drop = nn.Dropout(config.dropout),
            h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f = nn.LayerNorm(config.n_embd),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
        self.transformer.wte.weight = self.lm_head.weight
        self.apply(self._init_weights)

    def _init_weights(self, module):
        std = 0.02
        if hasattr(module, "NANOGPT_SCALE_INIT"):
            std *= (2*self.config.n_layer) ** -0.5
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=std)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=std) 

    def forward(self, idx, targets=None):
        B, T = idx.size()
        assert T <= self.config.block_size, "Cannot forward, model block size is exhausted."
        pos = torch.arange(0, T, device=idx.device).unsqueeze(0)
        pos_emb = self.transformer.wpe(pos)
        tok_emb = self.transformer.wte(idx)
        x = pos_emb + tok_emb
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        logits = self.lm_head(x)
        #return logits
        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))

        return logits, loss

# %%
import tiktoken
class DataLoader(torch.utils.data.Dataset):
    def __init__(self, B, T, data=None):
        self.data = data if data is not None else self.load_data()
        self.B = B
        self.T = T
        self.tokens = torch.tensor(self.data)
        self.current_pos = 0
        print(f"DataLoader initialized with {len(self.tokens)} tokens.")
        print(f"1 epoch will have {len(self.tokens) // (B * T)} batches.")

    def load_data(self):
        with open("./data/input.txt", "r") as f:
            text = f.read()
        return tiktoken.get_encoding("gpt2").encode(text)

    def getBatch(self):
        B, T = self.B, self.T
        buff = self.tokens[self.current_pos:self.current_pos+B*T+1]
        x = buff[:-1].view(B, T)
        y = buff[1:].view(B, T)
        self.current_pos += B*T
        if self.current_pos + B*T + 1 >= len(self.tokens):
            self.current_pos = 0
        return x, y

# %%
num_return_sequences = 5
max_length = 30
B = 4
T = 32

# import tiktoken
# enc = tiktoken.get_encoding("gpt2")
# tokens = enc.encode("Hello, I'm a large language model,")
# tokens = torch.tensor(tokens, dtype=torch.long)
# token = tokens.unsqueeze(0).repeat(num_return_sequences, 1)
# x = token

model = GPT(GPTConfig())
model = torch.compile(model)
model.eval()
train_loader = DataLoader(B=B, T=T)

# logits, loss = model(x, targets=y)
# print("Logits shape:", logits.shape, "Loss:", loss.item())

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)
for i in range(20):
    x, y = train_loader.getBatch()
    optimizer.zero_grad()
    logits, loss = model(x, targets=y)
    loss.backward()
    optimizer.step()
    print(f"Step {i+1}, Loss: {loss.item()}")

# while x.size(1) < max_length:
#     with torch.no_grad():
#         logits, loss = model(x, targets=y)
#         logits = logits[:, -1, :]
#         probs = F.softmax(logits, dim=-1)
#         topk_probs, topk_indices = torch.topk(probs, k=50, dim=-1)
#         ix = torch.multinomial(topk_probs, num_samples=1)
#         xcol = torch.gather(topk_indices, -1, ix) 
#         x = torch.cat((x, xcol), dim=1)

# for i in range(num_return_sequences):
#     tokens = x[i, :max_length].tolist()
#     decoded = enc.decode(tokens)
#     print(">", decoded)
# Out:
# c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\xpu\__init__.py:68: UserWarning: XPU device count is zero! (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\c10\xpu\XPUFunctions.cpp:113.)
#   return torch._C._xpu_getDeviceCount()
# DataLoader initialized with 338024 tokens.
# 1 epoch will have 2640 batches.
# ---------------------------------------------------------------------------
# InductorError                             Traceback (most recent call last)
# Cell In[9], line 25
#      23 x, y = train_loader.getBatch()
#      24 optimizer.zero_grad()
# ---> 25 logits, loss = model(x, targets=y)
#      26 loss.backward()
#      27 optimizer.step()
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_dynamo\eval_frame.py:472, in OptimizedModule.__call__(self, *args, **kwargs)
#     462     warnings.warn(
#     463         "Using `torch.compile(module)` when there are global hooks on "
#     464         "modules (e.g., from `register_module_forward_hook`); this will"
#    (...)
#     469         stacklevel=2,
#     470     )
#     471 with _set_in_optimized_module():
# --> 472     return super().__call__(*args, **kwargs)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_dynamo\eval_frame.py:1038, in _TorchDynamoContext.__call__.<locals>.compile_wrapper(*args, **kwargs)
#    1034     raise e.with_traceback(None) from e.__cause__  # User compiler error
#    1035 except ShortenTraceback as e:
#    1036     # Failures in the backend likely don't have useful
#    1037     # data in the TorchDynamo frames, so we strip them out.
# -> 1038     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#    1039 finally:
#    1040     # Restore the dynamic layer stack depth if necessary.
#    1041     set_eval_frame(None)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\compile_fx.py:1053, in _compile_fx_inner(gm, example_inputs, **graph_kwargs)
#    1051     raise
#    1052 except Exception as e:
# -> 1053     raise InductorError(e, currentframe()).with_traceback(
#    1054         e.__traceback__
#    1055     ) from None
#    1056 finally:
#    1057     TritonBundler.end_compile()
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\compile_fx.py:1037, in _compile_fx_inner(gm, example_inputs, **graph_kwargs)
#    1035 TritonBundler.begin_compile()
#    1036 try:
# -> 1037     mb_compiled_graph = fx_codegen_and_compile(
#    1038         gm, example_inputs, inputs_to_check, **graph_kwargs
#    1039     )
#    1040     assert mb_compiled_graph is not None
#    1041     mb_compiled_graph._time_taken_ns = time.time_ns() - start_time
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\compile_fx.py:1798, in fx_codegen_and_compile(gm, example_inputs, inputs_to_check, **graph_kwargs)
#    1795     scheme = _ProgressiveFxCompile(fast_scheme, scheme, progression_configs)
#    1797 # pyrefly: ignore [unbound-name]
# -> 1798 return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\compile_fx.py:1570, in _InProcessFxCompile.codegen_and_compile(self, gm, example_inputs, inputs_to_check, graph_kwargs)
#    1552         compiled_fn = AotCodeCompiler.compile(
#    1553             graph,
#    1554             wrapper_code.value,
#    (...)
#    1567             ],
#    1568         )
#    1569 else:
# -> 1570     compiled_module = graph.compile_to_module()
#    1571     compiled_fn = compiled_module.call
#    1572     compiled_fn_runner = getattr(
#    1573         compiled_module, "runner", None
#    1574     )
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\graph.py:2499, in GraphLowering.compile_to_module(self)
#    2492 def compile_to_module(self) -> CompiledModule:
#    2493     with dynamo_timed(
#    2494         "GraphLowering.compile_to_module",
#    2495         phase_name="code_gen",
#    2496         log_pt2_compile_event=True,
#    2497         dynamo_compile_column_us="inductor_code_gen_cumulative_compile_time_us",
#    2498     ):
# -> 2499         return self._compile_to_module()
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\graph.py:2505, in GraphLowering._compile_to_module(self)
#    2501 def _compile_to_module(self) -> CompiledModule:
#    2502     # If we're here, we don't have to worry about the kernel code, which is only
#    2503     # returned separately in AOTInductor mode.
#    2504     wrapper_code, _ = (
# -> 2505         self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
#    2506     )
#    2508     if isinstance(wrapper_code, ValueWithLineMap):
#    2509         mod = self._compile_to_module_lines(wrapper_code)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\graph.py:2441, in GraphLowering.codegen(self)
#    2438 V.debug.draw_orig_fx_graph(self.orig_gm, self.scheduler.nodes)
#    2440 self.wrapper_code.push_codegened_graph(self)
# -> 2441 self.scheduler.codegen()
#    2443 log.debug(
#    2444     "Finished codegen for all nodes. The list of kernel names available: %s",
#    2445     V.graph.all_codegen_kernel_names,
#    2446 )
#    2448 result = self.wrapper_code.generate(self.is_inference)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\scheduler.py:6592, in Scheduler.codegen(self)
#    6589 def codegen(self) -> None:
#    6590     with dynamo_timed("Scheduler.codegen"):
#    6591         return (
# -> 6592             self._codegen_partitions()
#    6593             if torch._inductor.config.graph_partition
#    6594             else self._codegen(self.nodes)
#    6595         )
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\scheduler.py:6732, in Scheduler._codegen_partitions(self)
#    6727 assert len(partition) >= 1, (
#    6728     f"Each partition must have at least one node but found {len(partition)}"
#    6729 )
#    6731 if signature.skip_cudagraph:
# -> 6732     self._codegen(partition)
#    6733 else:
#    6734     self._codegen_partition_wrapper(partition, signature)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\scheduler.py:6838, in Scheduler._codegen(self, nodes)
#    6835     self.get_backend(device).codegen_mix_order_reduction(node)
#    6836 elif isinstance(node, (FusedSchedulerNode, SchedulerNode)):
#    6837     # pyrefly: ignore [unbound-name]
# -> 6838     self.get_backend(device).codegen_node(node)
#    6839 else:
#    6840     assert isinstance(node, NopKernelSchedulerNode)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\codegen\cpp.py:5315, in CppScheduling.codegen_node(self, node)
#    5312 kernel_group = self.kernel_group
#    5314 if isinstance(node, OuterLoopFusedSchedulerNode):
# -> 5315     self.codegen_outer_loop_node(node)
#    5316 else:
#    5317     nodes: list[SchedulerNode] = node.get_nodes()  # type: ignore[assignment]
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\codegen\cpp.py:5289, in CppScheduling.codegen_outer_loop_node(self, node)
#    5282         kernel_group.finalize_kernel(
#    5283             outer_fusion_cpp_kernel_proxy,
#    5284             [*itertools.chain.from_iterable(nodes_list)],
#    5285         )
#    5287     return True
# -> 5289 if not try_outer_loop_fusion_with_local_buf(node):
#    5290     # Reset generated_cpp_vec_kernel_count to codegen again
#    5291     metrics.generated_cpp_vec_kernel_count = generated_cpp_vec_kernel_count
#    5292     cpp_kernel_proxy_list.clear()
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\codegen\cpp.py:5260, in CppScheduling.codegen_outer_loop_node.<locals>.try_outer_loop_fusion_with_local_buf(node)
#    5258 for _node in node.get_outer_nodes():
#    5259     assert isinstance(_node, (FusedSchedulerNode, SchedulerNode))
# -> 5260     cpp_kernel_proxy = self.kernel_proxy_cls(kernel_group)
#    5261     cpp_kernel_proxy.codegen_nodes(_node.get_nodes())  # type: ignore[arg-type]
#    5262     cpp_kernel_proxy_list.append(cpp_kernel_proxy)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\codegen\cpp.py:4022, in CppKernelProxy.__init__(self, kernel_group)
#    4020 self.loop_nest = None
#    4021 self.call_ranges = None
# -> 4022 self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
#    4023 self.kernels: list[CppKernel] = []
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:550, in pick_vec_isa()
#     547 if config.is_fbcode() and (platform.machine() in ["x86_64", "AMD64"]):
#     548     return VecAVX2()
# --> 550 _valid_vec_isa_list: list[VecISA] = valid_vec_isa_list()
#     551 if not _valid_vec_isa_list:
#     552     return invalid_vec_isa
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:537, in valid_vec_isa_list()
#     533     """
#     534     arch value is x86_64 on Linux, and the value is AMD64 on Windows.
#     535     """
#     536     _cpu_supported_x86_isa = x86_isa_checker()
# --> 537     isa_list.extend(
#     538         isa
#     539         for isa in supported_vec_isa_list
#     540         if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa
#     541     )
#     543 return isa_list
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:537, in <genexpr>(.0)
#     533     """
#     534     arch value is x86_64 on Linux, and the value is AMD64 on Windows.
#     535     """
#     536     _cpu_supported_x86_isa = x86_isa_checker()
# --> 537     isa_list.extend(
#     538         isa
#     539         for isa in supported_vec_isa_list
#     540         if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa
#     541     )
#     543 return isa_list
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:144, in VecISA.__bool__(self)
#     143 def __bool__(self) -> bool:
# --> 144     return self.__bool__impl(config.cpp.vec_isa_ok)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:154, in VecISA.__bool__impl(self, vec_isa_ok)
#     151 if config.is_fbcode():
#     152     return True
# --> 154 return self.check_build(VecISA._avx_code)
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:104, in VecISA.check_build(self, code)
#      94 from torch._inductor.codecache import get_lock_dir, LOCK_TIMEOUT, write
#      95 from torch._inductor.cpp_builder import (
#      96     CppBuilder,
#      97     CppTorchOptions,
#      98     normalize_path_separator,
#      99 )
#     101 key, input_path = write(
#     102     code,
#     103     "cpp",
# --> 104     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
#     105 )
#     106 from torch.utils._filelock import FileLock
#     108 lock_dir = get_lock_dir()
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:30, in _get_isa_dry_compile_fingerprint(isa_flags)
#      21 def _get_isa_dry_compile_fingerprint(isa_flags: str) -> str:
#      22     # ISA dry compile will cost about 1 sec time each startup time.
#      23     # Please check the issue: https://github.com/pytorch/pytorch/issues/100378
#    (...)
#      26     # and generated them to output binary hash path.
#      27     # It would optimize and skip compile existing binary.
#      28     from torch._inductor.cpp_builder import get_compiler_version_info, get_cpp_compiler
# ---> 30     compiler_info = get_compiler_version_info(get_cpp_compiler())
#      31     torch_version = torch.__version__
#      32     fingerprint = f"{compiler_info}={isa_flags}={torch_version}"
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpp_builder.py:383, in get_cpp_compiler()
#     381     compiler = os.environ.get("CXX", "cl")
#     382     compiler = normalize_path_separator(compiler)
# --> 383     check_compiler_exist_windows(compiler)
#     384     check_msvc_cl_language_id(compiler)
#     385 else:
#
# File c:\Users\Dhruv\anaconda3\envs\clean\Lib\site-packages\torch\_inductor\cpp_builder.py:142, in check_compiler_exist_windows(compiler)
#     140     subprocess.check_output([compiler, "/help"], stderr=subprocess.STDOUT)
#     141 except FileNotFoundError as exc:
# --> 142     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
#     143 except subprocess.SubprocessError:
#     144     # Expected that some compiler(clang, clang++) is exist, but they not support `/help` args.
#     145     pass
#
# InductorError: RuntimeError: Compiler: cl is not found.
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"

# %%
import torch
print("PyTorch version:", torch.__version__)
# Out:
# PyTorch version: 2.10.0+cpu

# %%
torch.xpu.is_available()
# Out:
# False

# %%
import intel_extension_for_pytorch as ipex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 import intel_extension_for_pytorch as ipex
#
# ModuleNotFoundError: No module named 'intel_extension_for_pytorch'
